# %%
{
  "response": {
    "header": {
      "resultCode": "00",
      "resultMsg": "NORMAL_CODE"
    },
    "body": {
      "totalCount": 10,
      "items": [
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "상행",
          "sectionName": "도화IC~옛시민회관사거리",
          "monthStatValue": "25",
          "mon": "25",
          "tue": "25",
          "wed": "25",
          "thu": "25",
          "fri": "25",
          "sat": "26",
          "sun": "27"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "상행",
          "sectionName": "간석오거리~동소정사거리",
          "monthStatValue": "29",
          "mon": "29",
          "tue": "29",
          "wed": "29",
          "thu": "29",
          "fri": "28",
          "sat": "29",
          "sun": "30"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "상행",
          "sectionName": "동소정사거리~황굴삼거리",
          "monthStatValue": "22",
          "mon": "21",
          "tue": "22",
          "wed": "21",
          "thu": "21",
          "fri": "21",
          "sat": "22",
          "sun": "22"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "상행",
          "sectionName": "심곡고가사거리~소사삼거리",
          "monthStatValue": "28",
          "mon": "27",
          "tue": "27",
          "wed": "28",
          "thu": "27",
          "fri": "27",
          "sat": "27",
          "sun": "30"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "상행",
          "sectionName": "소사삼거리~고척교교차로",
          "monthStatValue": "23",
          "mon": "23",
          "tue": "23",
          "wed": "23",
          "thu": "23",
          "fri": "23",
          "sat": "24",
          "sun": "25"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "하행",
          "sectionName": "고척교교차로~소사삼거리",
          "monthStatValue": "25",
          "mon": "25",
          "tue": "25",
          "wed": "25",
          "thu": "25",
          "fri": "24",
          "sat": "25",
          "sun": "26"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "하행",
          "sectionName": "소사삼거리~심곡고가사거리",
          "monthStatValue": "22",
          "mon": "23",
          "tue": "22",
          "wed": "22",
          "thu": "22",
          "fri": "21",
          "sat": "23",
          "sun": "24"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "하행",
          "sectionName": "황굴삼거리~동소정사거리",
          "monthStatValue": "23",
          "mon": "23",
          "tue": "23",
          "wed": "23",
          "thu": "23",
          "fri": "22",
          "sat": "23",
          "sun": "24"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "하행",
          "sectionName": "동소정사거리~간석오거리",
          "monthStatValue": "30",
          "mon": "30",
          "tue": "29",
          "wed": "28",
          "thu": "30",
          "fri": "29",
          "sat": "31",
          "sun": "30"
        },
        {
          "statDate": "202301",
          "roadName": "경인로",
          "direction": "하행",
          "sectionName": "옛시민회관사거리~도화IC",
          "monthStatValue": "23",
          "mon": "23",
          "tue": "23",
          "wed": "23",
          "thu": "23",
          "fri": "23",
          "sat": "23",
          "sun": "24"
        }
      ],
      "pageNo": 1,
      "numOfRows": 100
    }
  }
}
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'},
#   'body': {'totalCount': 10,
#    'items': [{'statDate': '202301',
#      'roadName': '경인로',
#      'direction': '상행',
#      'sectionName': '도화IC~옛시민회관사거리',
#      'monthStatValue': '25',
#      'mon': '25',
#      'tue': '25',
#      'wed': '25',
#      'thu': '25',
#      'fri': '25',
#      'sat': '26',
#      'sun': '27'},
#     {'statDate': '202301',
#      'roadName': '경인로',
#      'direction': '상행',
#      'sectionName': '간석오거리~동소정사거리',
#      'monthStatValue': '29',
#      'mon': '29',
#      'tue': '29',
#      'wed': '29',
#      'thu': '29',
#      'fri': '28',
#      'sat': '29',
#      'sun': '30'},
#     {'statDate': '202301',
#      'roadName': '경인로',
#      'direction': '상행',
#      'sectionName': '동소정사거리~황굴삼거리',
#      'monthStatValue': '22',
#      'mon': '21',
#      'tue': '22',
#      'wed': '21',
#      'thu': '21',
#      'fri': '21',
#      'sat': '22',
#      'sun': '22'},
# ...
